# %% [markdown]
# ## Test the loading of a csv file

# %%
from civiclink.pipeline.dataset import TabularDataset

table_path = "data/dummy.csv"

dataset = TabularDataset(table_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 from civiclink.pipeline.dataset import TabularDataset
#       3 table_path = "data/dummy.csv"
# ----> 5 dataset = TabularDataset(table_path)
#
# TypeError: TabularDataset.__init__() missing 3 required positional arguments: 'numeric_cols', 'categorical_cols', and 'target_col'
